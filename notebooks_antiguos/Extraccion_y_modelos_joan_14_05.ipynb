# %% [markdown]
# # Clasificador de reseñas

# %% [markdown]
# - **Joan Pedro Bruxola**
# - **Julio García Bustos**
# - **Marcos Rosique Martínez**
# - **Mario Soto Ramos**

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
from langdetect import detect, LangDetectException
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Extracción de URLs

# %% [markdown]
# ### URLs de las películas

# %%
# Parámetros para la URL (puedes cambiar estos valores dinámicamente)
params = {
    "releaseYearMin": 2015,  # Año mínimo
    "releaseYearMax": 2020,  # Año máximo
    "page": 1                # Número de página
}

n = 24  # Número de películas que queremos obtener

# URL base
url = "https://www.metacritic.com/browse/movie/"

# Realizamos la solicitud GET con los parámetros
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers, params=params)

# Comprobamos si la solicitud fue exitosa
if response.status_code == 200:
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Encontramos todos los enlaces a las películas
    movie_links_positive = soup.find_all("a", class_="c-finderProductCard_container g-color-gray80 u-grid")
    
    # Lista para almacenar los enlaces
    links_positive = []

    # Extraemos los enlaces de las primeras 24 películas y los guardamos en la lista
    for idx, link in enumerate(movie_links_positive[:n]):  # Solo las primeras 24
        href = link.get("href")
        if href:
            full_url = f"https://www.metacritic.com{href}"
            links_positive.append(full_url)  # Guardamos el enlace en la lista
            print(f"Película {idx+1}: {full_url}")
    
    # Opcional: Puedes ver todos los enlaces almacenados
    print("\nLista de enlaces almacenados:")
    print(links_positive)

else:
    print("Error al acceder a la página.")
# Out:
# Película 1: https://www.metacritic.com/movie/moonlight-2016/
# Película 2: https://www.metacritic.com/movie/parasite/
# Película 3: https://www.metacritic.com/movie/roma/
# Película 4: https://www.metacritic.com/movie/manchester-by-the-sea/
# Película 5: https://www.metacritic.com/movie/small-axe-lovers-rock/
# Película 6: https://www.metacritic.com/movie/portrait-of-a-lady-on-fire/
# Película 7: https://www.metacritic.com/movie/i-am-not-your-negro/
# Película 8: https://www.metacritic.com/movie/collective/
# Película 9: https://www.metacritic.com/movie/carol/
# Película 10: https://www.metacritic.com/movie/amazing-grace-1972/
# Película 11: https://www.metacritic.com/movie/dunkirk/
# Película 12: https://www.metacritic.com/movie/45-years/
# Película 13: https://www.metacritic.com/movie/the-irishman/
# Película 14: https://www.metacritic.com/movie/inside-out-2015/
# Película 15: https://www.metacritic.com/movie/faces-places/
# Película 16: https://www.metacritic.com/movie/call-me-by-your-name/
# Película 17: https://www.metacritic.com/movie/marriage-story/
# Película 18: https://www.metacritic.com/movie/la-la-land/
# Película 19: https://www.metacritic.com/movie/lady-bird/
# Película 20: https://www.metacritic.com/movie/david-byrnes-american-utopia/
# Película 21: https://www.metacritic.com/movie/shoplifters/
# Película 22: https://www.metacritic.com/movie/shoah-four-sisters/
# Película 23: https://www.metacritic.com/movie/toni-erdmann/
# Película 24: https://www.metacritic.com/movie/uncut-gems/
#
# Lista de enlaces almacenados:
# ['https://www.metacritic.com/movie/moonlight-2016/', 'https://www.metacritic.com/movie/parasite/', 'https://www.metacritic.com/movie/roma/', 'https://www.metacritic.com/movie/manchester-by-the-sea/', 'https://www.metacritic.com/movie/small-axe-lovers-rock/', 'https://www.metacritic.com/movie/portrait-of-a-lady-on-fire/', 'https://www.metacritic.com/movie/i-am-not-your-negro/', 'https://www.metacritic.com/movie/collective/', 'https://www.metacritic.com/movie/carol/', 'https://www.metacritic.com/movie/amazing-grace-1972/', 'https://www.metacritic.com/movie/dunkirk/', 'https://www.metacritic.com/movie/45-years/', 'https://www.metacritic.com/movie/the-irishman/', 'https://www.metacritic.com/movie/inside-out-2015/', 'https://www.metacritic.com/movie/faces-places/', 'https://www.metacritic.com/movie/call-me-by-your-name/', 'https://www.metacritic.com/movie/marriage-story/', 'https://www.metacritic.com/movie/la-la-land/', 'https://www.metacritic.com/movie/lady-bird/', 'https://www.metacritic.com/movie/david-byrnes-american-utopia/', 'https://www.metacritic.com/movie/shoplifters/', 'https://www.metacritic.com/movie/shoah-four-sisters/', 'https://www.metacritic.com/movie/toni-erdmann/', 'https://www.metacritic.com/movie/uncut-gems/']

# %%
# Parámetros para la URL (puedes cambiar estos valores dinámicamente)
params = {
    "releaseYearMin": 2015,  # Año mínimo
    "releaseYearMax": 2020,  # Año máximo
    "page": 149                # Número de página
}

# URL base
url = "https://www.metacritic.com/browse/movie/"

# Realizamos la solicitud GET con los parámetros
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers, params=params)

# Comprobamos si la solicitud fue exitosa
if response.status_code == 200:
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Encontramos todos los enlaces a las películas
    movie_links_worst = soup.find_all("a", class_="c-finderProductCard_container g-color-gray80 u-grid")
    
    # Lista para almacenar los enlaces
    links_worst = []

    # Extraemos los enlaces de las primeras 24 películas y los guardamos en la lista
    for idx, link in enumerate(movie_links_worst[:n]):  # Solo las primeras 24
        href = link.get("href")
        if href:
            full_url = f"https://www.metacritic.com{href}"
            links_worst.append(full_url)  # Guardamos el enlace en la lista
            print(f"Película {idx+1}: {full_url}")
    
    # Opcional: Puedes ver todos los enlaces almacenados
    print("\nLista de enlaces almacenados:")
    print(links_worst)

else:
    print("Error al acceder a la página.")
# Out:
# Película 1: https://www.metacritic.com/movie/search-party/
# Película 2: https://www.metacritic.com/movie/max-steel/
# Película 3: https://www.metacritic.com/movie/enter-the-dangerous-mind/
# Película 4: https://www.metacritic.com/movie/home-sweet-hell/
# Película 5: https://www.metacritic.com/movie/martyrs/
# Película 6: https://www.metacritic.com/movie/the-tax-collector/
# Película 7: https://www.metacritic.com/movie/gods-not-dead-2/
# Película 8: https://www.metacritic.com/movie/blumhouses-fantasy-island/
# Película 9: https://www.metacritic.com/movie/norm-of-the-north/
# Película 10: https://www.metacritic.com/movie/a-family-man/
# Película 11: https://www.metacritic.com/movie/geostorm/
# Película 12: https://www.metacritic.com/movie/dirty-grandpa/
# Película 13: https://www.metacritic.com/movie/211/
# Película 14: https://www.metacritic.com/movie/the-clapper/
# Película 15: https://www.metacritic.com/movie/just-getting-started/
# Película 16: https://www.metacritic.com/movie/life-itself-2018/
# Película 17: https://www.metacritic.com/movie/accidental-love/
# Película 18: https://www.metacritic.com/movie/reprisal/
# Película 19: https://www.metacritic.com/movie/the-lovers/
# Película 20: https://www.metacritic.com/movie/replicas-2018/
# Película 21: https://www.metacritic.com/movie/polar/
# Película 22: https://www.metacritic.com/movie/the-vanishing-of-sidney-hall/
# Película 23: https://www.metacritic.com/movie/the-fanatic/
# Película 24: https://www.metacritic.com/movie/the-ridiculous-6/
#
# Lista de enlaces almacenados:
# ['https://www.metacritic.com/movie/search-party/', 'https://www.metacritic.com/movie/max-steel/', 'https://www.metacritic.com/movie/enter-the-dangerous-mind/', 'https://www.metacritic.com/movie/home-sweet-hell/', 'https://www.metacritic.com/movie/martyrs/', 'https://www.metacritic.com/movie/the-tax-collector/', 'https://www.metacritic.com/movie/gods-not-dead-2/', 'https://www.metacritic.com/movie/blumhouses-fantasy-island/', 'https://www.metacritic.com/movie/norm-of-the-north/', 'https://www.metacritic.com/movie/a-family-man/', 'https://www.metacritic.com/movie/geostorm/', 'https://www.metacritic.com/movie/dirty-grandpa/', 'https://www.metacritic.com/movie/211/', 'https://www.metacritic.com/movie/the-clapper/', 'https://www.metacritic.com/movie/just-getting-started/', 'https://www.metacritic.com/movie/life-itself-2018/', 'https://www.metacritic.com/movie/accidental-love/', 'https://www.metacritic.com/movie/reprisal/', 'https://www.metacritic.com/movie/the-lovers/', 'https://www.metacritic.com/movie/replicas-2018/', 'https://www.metacritic.com/movie/polar/', 'https://www.metacritic.com/movie/the-vanishing-of-sidney-hall/', 'https://www.metacritic.com/movie/the-fanatic/', 'https://www.metacritic.com/movie/the-ridiculous-6/']

# %%
# Parámetros para la URL (puedes cambiar estos valores dinámicamente)
params = {
    "releaseYearMin": 2015,  # Año mínimo
    "releaseYearMax": 2020,  # Año máximo
    "page": 90                # Número de página
}

# URL base
url = "https://www.metacritic.com/browse/movie/"

# Realizamos la solicitud GET con los parámetros
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers, params=params)

# Comprobamos si la solicitud fue exitosa
if response.status_code == 200:
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Encontramos todos los enlaces a las películas
    movie_links_neutral = soup.find_all("a", class_="c-finderProductCard_container g-color-gray80 u-grid")
    
    # Lista para almacenar los enlaces
    links_neutral = []

    # Extraemos los enlaces de las primeras 24 películas y los guardamos en la lista
    for idx, link in enumerate(movie_links_neutral[:n]):  # Solo las primeras 24
        href = link.get("href")
        if href:
            full_url = f"https://www.metacritic.com{href}"
            links_neutral.append(full_url)  # Guardamos el enlace en la lista
            print(f"Película {idx+1}: {full_url}")
    
    # Opcional: Puedes ver todos los enlaces almacenados
    print("\nLista de enlaces almacenados:")
    print(links_neutral)

else:
    print("Error al acceder a la página.")
# Out:
# Película 1: https://www.metacritic.com/movie/i-smile-back/
# Película 2: https://www.metacritic.com/movie/between-two-ferns-the-movie/
# Película 3: https://www.metacritic.com/movie/all-is-true/
# Película 4: https://www.metacritic.com/movie/champs/
# Película 5: https://www.metacritic.com/movie/amnesia-2015/
# Película 6: https://www.metacritic.com/movie/crooked-house/
# Película 7: https://www.metacritic.com/movie/judy-punch/
# Película 8: https://www.metacritic.com/movie/ottolenghi-and-the-cakes-of-versailles/
# Película 9: https://www.metacritic.com/movie/doctor-sleep/
# Película 10: https://www.metacritic.com/movie/the-boy-downstairs/
# Película 11: https://www.metacritic.com/movie/the-rachel-divide/
# Película 12: https://www.metacritic.com/movie/extraordinary-tales/
# Película 13: https://www.metacritic.com/movie/sing/
# Película 14: https://www.metacritic.com/movie/lizzie/
# Película 15: https://www.metacritic.com/movie/the-lovebirds/
# Película 16: https://www.metacritic.com/movie/on-the-basis-of-sex/
# Película 17: https://www.metacritic.com/movie/run-all-night/
# Película 18: https://www.metacritic.com/movie/bridget-joness-baby/
# Película 19: https://www.metacritic.com/movie/suntan/
# Película 20: https://www.metacritic.com/movie/elvis-nixon/
# Película 21: https://www.metacritic.com/movie/the-final-girls/
# Película 22: https://www.metacritic.com/movie/cars-3/
# Película 23: https://www.metacritic.com/movie/absolutely-fabulous-the-movie/
# Película 24: https://www.metacritic.com/movie/the-dead-lands/
#
# Lista de enlaces almacenados:
# ['https://www.metacritic.com/movie/i-smile-back/', 'https://www.metacritic.com/movie/between-two-ferns-the-movie/', 'https://www.metacritic.com/movie/all-is-true/', 'https://www.metacritic.com/movie/champs/', 'https://www.metacritic.com/movie/amnesia-2015/', 'https://www.metacritic.com/movie/crooked-house/', 'https://www.metacritic.com/movie/judy-punch/', 'https://www.metacritic.com/movie/ottolenghi-and-the-cakes-of-versailles/', 'https://www.metacritic.com/movie/doctor-sleep/', 'https://www.metacritic.com/movie/the-boy-downstairs/', 'https://www.metacritic.com/movie/the-rachel-divide/', 'https://www.metacritic.com/movie/extraordinary-tales/', 'https://www.metacritic.com/movie/sing/', 'https://www.metacritic.com/movie/lizzie/', 'https://www.metacritic.com/movie/the-lovebirds/', 'https://www.metacritic.com/movie/on-the-basis-of-sex/', 'https://www.metacritic.com/movie/run-all-night/', 'https://www.metacritic.com/movie/bridget-joness-baby/', 'https://www.metacritic.com/movie/suntan/', 'https://www.metacritic.com/movie/elvis-nixon/', 'https://www.metacritic.com/movie/the-final-girls/', 'https://www.metacritic.com/movie/cars-3/', 'https://www.metacritic.com/movie/absolutely-fabulous-the-movie/', 'https://www.metacritic.com/movie/the-dead-lands/']

# %% [markdown]
# ### URLs de las reseñas

# %%
# Definir los filtros y las listas
filters = ['Positive%20Reviews', 'Mixed%20Reviews', 'Negative%20Reviews']
link_lists = [links_positive, links_neutral, links_worst]

# Lista para almacenar los enlaces
review_links = []

# Iterar sobre los filtros y las listas de enlaces
for filter_type in filters:
    for link_list in link_lists:
        review_links += [f"{url}user-reviews/?filter={filter_type}" for url in link_list]

# Ahora review_links contiene todas las URLs concatenadas
print(review_links)
print(f"Tamaño de review_links: {len(review_links)}")
# Out:
# ['https://www.metacritic.com/movie/moonlight-2016/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/parasite/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/roma/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/manchester-by-the-sea/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/small-axe-lovers-rock/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/portrait-of-a-lady-on-fire/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/i-am-not-your-negro/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/collective/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/carol/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/amazing-grace-1972/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/dunkirk/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/45-years/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/the-irishman/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/inside-out-2015/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/faces-places/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/call-me-by-your-name/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/marriage-story/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/la-la-land/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/lady-bird/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/david-byrnes-american-utopia/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/shoplifters/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/shoah-four-sisters/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/toni-erdmann/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/uncut-gems/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/i-smile-back/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/between-two-ferns-the-movie/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/all-is-true/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/champs/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/amnesia-2015/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/crooked-house/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/judy-punch/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/ottolenghi-and-the-cakes-of-versailles/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/doctor-sleep/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/the-boy-downstairs/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/the-rachel-divide/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/extraordinary-tales/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/sing/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/lizzie/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/the-lovebirds/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/on-the-basis-of-sex/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/run-all-night/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/bridget-joness-baby/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/suntan/user-reviews/?filter=Positive%20Reviews', 'https://www.metacritic.com/movie/elvis-nixon/user-reviews/?filter=Positive%20Rev ...
# Tamaño de review_links: 288

# %% [markdown]
# ## Extracción y almacenamiento de reseñas

# %%
# Número de reseñas por película
n_res = 20

# %%
def get_user_reviews_selenium(movie_url, max_pages=1):  # Cambié max_pages a 1 para limitar la cantidad de páginas
    chrome_options = Options()
    #chrome_options.add_argument("--headless")  # Ejecutar sin abrir ventana
    chrome_options.add_argument("--disable-gpu")
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("user-agent=Mozilla/5.0")

    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

    all_reviews = []

    for page in range(max_pages):  # Solo una página por URL
        url = f"{movie_url}&page={page + 1}"  # Se añade la página actual a la URL
        driver.get(url)
        time.sleep(2)  # Espera a que cargue JavaScript

        soup = BeautifulSoup(driver.page_source, "html.parser")

        review_containers = soup.find_all("div", attrs={"data-testid": "product-review"})

        for container in review_containers:
            score_tag = container.find("div", class_="c-siteReviewScore")
            score = score_tag.get_text(strip=True) if score_tag else "No score"

            user_tag = container.find("a", class_="c-siteReviewHeader_username")
            username = user_tag.get_text(strip=True) if user_tag else "No username"

            date_tag = container.find("div", class_="c-siteReviewHeader_reviewDate")
            date = date_tag.get_text(strip=True) if date_tag else "No date"

            quote_tag = container.find("div", class_="c-siteReview_quote")
            review_text = quote_tag.get_text(strip=True) if quote_tag else "No review text"

            all_reviews.append({
                "movie_url": movie_url,  # Añadimos la URL de la película
                "username": username,
                "date": date,
                "score": score,
                "review": review_text
            })

        if len(all_reviews) >= n_res:  # Si ya tenemos 20 reseñas, salimos del bucle
            break

    driver.quit()
    return all_reviews


# Lista para almacenar todas las reseñas
all_reviews_data = []

# Extraer 10 reseñas para cada enlace en review_links
for movie_url in review_links:
    print(f"Extrayendo reseñas de: {movie_url}")
    reviews = get_user_reviews_selenium(movie_url)

    # Almacenar las reseñas en la lista
    for review in reviews[:n_res]:  # Almacenamos solo las primeras 10 reseñas
        all_reviews_data.append(review)

# Convertir la lista de reseñas a un DataFrame de pandas
df_reviews = pd.DataFrame(all_reviews_data)

# Mostrar las primeras filas del DataFrame
print(df_reviews.head())
# Out:
# Extrayendo reseñas de: https://www.metacritic.com/movie/moonlight-2016/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/parasite/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/roma/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/manchester-by-the-sea/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/small-axe-lovers-rock/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/portrait-of-a-lady-on-fire/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/i-am-not-your-negro/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/collective/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/carol/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/amazing-grace-1972/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/dunkirk/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/45-years/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-irishman/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/inside-out-2015/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/faces-places/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/call-me-by-your-name/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/marriage-story/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/la-la-land/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/lady-bird/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/david-byrnes-american-utopia/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/shoplifters/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/shoah-four-sisters/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/toni-erdmann/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/uncut-gems/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/i-smile-back/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/between-two-ferns-the-movie/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/all-is-true/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/champs/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/amnesia-2015/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/crooked-house/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/judy-punch/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/ottolenghi-and-the-cakes-of-versailles/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/doctor-sleep/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-boy-downstairs/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-rachel-divide/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/extraordinary-tales/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/sing/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/lizzie/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-lovebirds/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/on-the-basis-of-sex/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/run-all-night/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/bridget-joness-baby/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/suntan/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/elvis-nixon/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-final-girls/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/cars-3/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/absolutely-fabulous-the-movie/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-dead-lands/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/search-party/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/max-steel/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/enter-the-dangerous-mind/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/home-sweet-hell/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/martyrs/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-tax-collector/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/gods-not-dead-2/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/blumhouses-fantasy-island/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/norm-of-the-north/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/a-family-man/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/geostorm/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/dirty-grandpa/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/211/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-clapper/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/just-getting-started/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/life-itself-2018/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/accidental-love/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/reprisal/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-lovers/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/replicas-2018/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/polar/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-vanishing-of-sidney-hall/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-fanatic/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-ridiculous-6/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/breath/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-woman-who-loves-giraffes/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/yes-god-yes/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/lucky-grandma/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/girls-trip/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/florence-foster-jenkins/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-farewell-party/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/francofonia/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/mavis!/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/dogman/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/cam/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/sweetheart/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/big-sonia/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/letters-from-baghdad/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-great-buster-a-celebration/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/tomorrow/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-brink/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/shazam!/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/tikkun/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/sworn-virgin/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-music-of-strangers-yo-yo-ma-and-the-silk-road-ensemble/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/fort-tilden/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/never-steady-never-still/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/a-murder-in-the-park/user-reviews/?filter=Positive%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/moonlight-2016/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/parasite/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/roma/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/manchester-by-the-sea/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/small-axe-lovers-rock/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/portrait-of-a-lady-on-fire/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/i-am-not-your-negro/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/collective/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/carol/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/amazing-grace-1972/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/dunkirk/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/45-years/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-irishman/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/inside-out-2015/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/faces-places/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/call-me-by-your-name/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/marriage-story/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/la-la-land/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/lady-bird/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/david-byrnes-american-utopia/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/shoplifters/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/shoah-four-sisters/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/toni-erdmann/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/uncut-gems/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/i-smile-back/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/between-two-ferns-the-movie/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/all-is-true/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/champs/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/amnesia-2015/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/crooked-house/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/judy-punch/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/ottolenghi-and-the-cakes-of-versailles/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/doctor-sleep/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-boy-downstairs/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-rachel-divide/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/extraordinary-tales/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/sing/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/lizzie/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-lovebirds/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/on-the-basis-of-sex/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/run-all-night/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/bridget-joness-baby/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/suntan/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/elvis-nixon/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-final-girls/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/cars-3/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/absolutely-fabulous-the-movie/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-dead-lands/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/search-party/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/max-steel/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/enter-the-dangerous-mind/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/home-sweet-hell/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/martyrs/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-tax-collector/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/gods-not-dead-2/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/blumhouses-fantasy-island/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/norm-of-the-north/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/a-family-man/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/geostorm/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/dirty-grandpa/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/211/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-clapper/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/just-getting-started/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/life-itself-2018/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/accidental-love/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/reprisal/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-lovers/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/replicas-2018/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/polar/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-vanishing-of-sidney-hall/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-fanatic/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-ridiculous-6/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/breath/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-woman-who-loves-giraffes/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/yes-god-yes/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/lucky-grandma/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/girls-trip/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/florence-foster-jenkins/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-farewell-party/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/francofonia/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/mavis!/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/dogman/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/cam/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/sweetheart/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/big-sonia/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/letters-from-baghdad/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-great-buster-a-celebration/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/tomorrow/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-brink/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/shazam!/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/tikkun/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/sworn-virgin/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-music-of-strangers-yo-yo-ma-and-the-silk-road-ensemble/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/fort-tilden/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/never-steady-never-still/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/a-murder-in-the-park/user-reviews/?filter=Mixed%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/moonlight-2016/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/parasite/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/roma/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/manchester-by-the-sea/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/small-axe-lovers-rock/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/portrait-of-a-lady-on-fire/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/i-am-not-your-negro/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/collective/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/carol/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/amazing-grace-1972/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/dunkirk/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/45-years/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-irishman/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/inside-out-2015/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/faces-places/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/call-me-by-your-name/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/marriage-story/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/la-la-land/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/lady-bird/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/david-byrnes-american-utopia/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/shoplifters/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/shoah-four-sisters/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/toni-erdmann/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/uncut-gems/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/i-smile-back/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/between-two-ferns-the-movie/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/all-is-true/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/champs/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/amnesia-2015/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/crooked-house/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/judy-punch/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/ottolenghi-and-the-cakes-of-versailles/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/doctor-sleep/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-boy-downstairs/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-rachel-divide/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/extraordinary-tales/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/sing/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/lizzie/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-lovebirds/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/on-the-basis-of-sex/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/run-all-night/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/bridget-joness-baby/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/suntan/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/elvis-nixon/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-final-girls/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/cars-3/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/absolutely-fabulous-the-movie/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-dead-lands/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/search-party/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/max-steel/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/enter-the-dangerous-mind/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/home-sweet-hell/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/martyrs/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-tax-collector/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/gods-not-dead-2/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/blumhouses-fantasy-island/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/norm-of-the-north/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/a-family-man/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/geostorm/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/dirty-grandpa/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/211/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-clapper/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/just-getting-started/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/life-itself-2018/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/accidental-love/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/reprisal/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-lovers/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/replicas-2018/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/polar/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-vanishing-of-sidney-hall/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-fanatic/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-ridiculous-6/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/breath/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-woman-who-loves-giraffes/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/yes-god-yes/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/lucky-grandma/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/girls-trip/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/florence-foster-jenkins/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-farewell-party/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/francofonia/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/mavis!/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/dogman/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/cam/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/sweetheart/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/big-sonia/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/letters-from-baghdad/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-great-buster-a-celebration/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/tomorrow/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-brink/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/shazam!/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/tikkun/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/sworn-virgin/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/the-music-of-strangers-yo-yo-ma-and-the-silk-road-ensemble/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/fort-tilden/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/never-steady-never-still/user-reviews/?filter=Negative%20Reviews
# Extrayendo reseñas de: https://www.metacritic.com/movie/a-murder-in-the-park/user-reviews/?filter=Negative%20Reviews
#                                            movie_url        username  \
# 0  https://www.metacritic.com/movie/moonlight-201...  Randomsquirrel
# 1  https://www.metacritic.com/movie/moonlight-201...  isabellacosta8
# 2  https://www.metacritic.com/movie/moonlight-201...     Gabrielx593
# 3  https://www.metacritic.com/movie/moonlight-201...            NWR1
# 4  https://www.metacritic.com/movie/moonlight-201...    Alexmarshall
#
#            date score                                             review
# 0  Jan 15, 2025    10  It was an absolutely brilliant film. Character...
# 1  Oct 10, 2024    10    [SPOILER ALERT: This review contains spoilers.]
# 2   Oct 9, 2024    10    [SPOILER ALERT: This review contains spoilers.]
# 3  Mar 31, 2024     9  I haven’t felt this much emotion in a long tim...
# 4  Oct 16, 2023    10                                      Reallyamazing

# %%
# Guardar el DataFrame en un archivo CSV
df_reviews.to_csv("reviews_finales.csv", index=True)

# %% [markdown]
# ## Preprocesamiento

# %%
# Leer el archivo CSV y establecer la columna 'Unnamed: 0' como índice
df = pd.read_csv("reviews_finales.csv")

# %%
df.head()
# Out:
#                                            movie_url        username  \
# 0  https://www.metacritic.com/movie/moonlight-201...  Randomsquirrel
# 1  https://www.metacritic.com/movie/moonlight-201...  isabellacosta8
# 2  https://www.metacritic.com/movie/moonlight-201...     Gabrielx593
# 3  https://www.metacritic.com/movie/moonlight-201...            NWR1
# 4  https://www.metacritic.com/movie/moonlight-201...    Alexmarshall
#
#            date  score                                             review
# 0  Jan 15, 2025     10  It was an absolutely brilliant film. Character...
# 1  Oct 10, 2024     10    [SPOILER ALERT: This review contains spoilers.]
# 2   Oct 9, 2024     10    [SPOILER ALERT: This review contains spoilers.]
# 3  Mar 31, 2024      9  I haven’t felt this much emotion in a long tim...
# 4  Oct 16, 2023     10                                      Reallyamazing

# %%
df.shape
# Out:
# (1814, 5)

# %%
# Aplicar la extracción y transformación del nombre de la película a la columna "movie_url"
df['movie_url'] = df['movie_url'].apply(lambda x: re.search(r'/movie/([^/]+)', x).group(1).replace('-', ' ').title())

# Renombrar la columna "movie_url" a "movie"
df = df.rename(columns={"movie_url": "movie"})

df.head(5)
# Out:
#             movie        username          date  score  \
# 0  Moonlight 2016  Randomsquirrel  Jan 15, 2025     10
# 1  Moonlight 2016  isabellacosta8  Oct 10, 2024     10
# 2  Moonlight 2016     Gabrielx593   Oct 9, 2024     10
# 3  Moonlight 2016            NWR1  Mar 31, 2024      9
# 4  Moonlight 2016    Alexmarshall  Oct 16, 2023     10
#
#                                               review
# 0  It was an absolutely brilliant film. Character...
# 1    [SPOILER ALERT: This review contains spoilers.]
# 2    [SPOILER ALERT: This review contains spoilers.]
# 3  I haven’t felt this much emotion in a long tim...
# 4                                      Reallyamazing

# %%
# Función para manejar excepciones y textos vacíos
def safe_detect(text):
    try:
        if text.strip():  # Asegurarse de que el texto no esté vacío
            return detect(text)
        else:
            return None  # Si el texto está vacío, devuelve None
    except LangDetectException:
        return None  # Si no puede detectar el idioma, devuelve None

# Eliminar las filas donde la columna 'review' contiene "SPOILER ALERT" y crear la columna 'sentiment' basada en la columna 'score'
df = (df[~df['review'].str.contains("SPOILER ALERT", case=True, na=False)]
              .assign(language = df['review'].apply(safe_detect)))

# Filtrar el DataFrame para quedarse solo con las filas donde el idioma es 'en'
df = df[df['language'] == 'en']

df = df.drop('language', axis = 1)

df.head(5)
# Out:
#             movie        username          date  score  \
# 0  Moonlight 2016  Randomsquirrel  Jan 15, 2025     10
# 3  Moonlight 2016            NWR1  Mar 31, 2024      9
# 5  Moonlight 2016        Youngoth  Oct 16, 2023     10
# 6  Moonlight 2016       Dominik08  Aug 15, 2023      8
# 7  Moonlight 2016        AgentLvi  Jun 27, 2023      7
#
#                                               review
# 0  It was an absolutely brilliant film. Character...
# 3  I haven’t felt this much emotion in a long tim...
# 5  This movie is masterpiece, so well done. Deser...
# 6  A refined production, with no obvious weakness...
# 7  Decent movie. The story is so --so, scoring is...

# %%
df['sentiment'] = df['score'].apply(lambda x: 'NEG' if x <= 3 else ('NEU' if 4 <= x <= 6 else 'POS'))

df.head(5)
# Out:
#             movie        username          date  score  \
# 0  Moonlight 2016  Randomsquirrel  Jan 15, 2025     10
# 3  Moonlight 2016            NWR1  Mar 31, 2024      9
# 5  Moonlight 2016        Youngoth  Oct 16, 2023     10
# 6  Moonlight 2016       Dominik08  Aug 15, 2023      8
# 7  Moonlight 2016        AgentLvi  Jun 27, 2023      7
#
#                                               review sentiment
# 0  It was an absolutely brilliant film. Character...       POS
# 3  I haven’t felt this much emotion in a long tim...       POS
# 5  This movie is masterpiece, so well done. Deser...       POS
# 6  A refined production, with no obvious weakness...       POS
# 7  Decent movie. The story is so --so, scoring is...       POS

# %%
df.shape
# Out:
# (1545, 6)

# %% [markdown]
# Instalación del modelo de spaCy
#
# Para instalar el modelo `en_core_web_md` de **spaCy**, ejecuta el siguiente comando en tu **Anaconda Prompt** o **Terminal**:
#
# ```bash
# python -m spacy download en_core_web_md

# %%
import spacy
import string
nlp = spacy.load('en_core_web_md')

# %%
from spacy.lang.en.stop_words import STOP_WORDS
print(STOP_WORDS)
# Out:
# {'anyone', '’ll', 'until', 'give', 'us', 'towards', 'yourselves', 'others', 'themselves', 'however', 'latter', 'enough', 'you', 'done', 'several', 'alone', 'almost', 'some', 'very', 'nor', 'its', 'always', 'their', 'so', '’s', 'among', 'been', 'hereby', 'ever', 'under', 're', 'than', 'meanwhile', 'whereas', 'am', 'amount', 'anywhere', 'may', 'again', 'did', 'at', 'when', 'ten', "n't", 'everyone', 'same', 'we', 'name', 'nowhere', 'against', 'yourself', '’m', 'else', 'our', 'whoever', 'namely', 'without', 'formerly', "'m", 'hundred', 'mostly', 'move', 'while', 'few', 'but', 'except', 'no', 'seems', 'was', '‘ll', 'hence', 'why', 'perhaps', 'please', 'must', '’d', "'ve", 'own', 'they', 'be', 'hereupon', 'something', 'keep', "'s", 'ourselves', 'hers', 'third', 'here', "'re", 'though', 'for', 'all', 'n’t', 'were', 'well', 'via', 'a', 'if', 'upon', 'whither', 'any', 'she', 'him', 'make', 'eight', 'whose', 'thru', 'noone', 'had', 'nobody', 'after', 'sometime', 'thereby', 'now', 'somewhere', 'cannot', 'unless', 'he', 'your', 'seemed', 'below', 'often', 'first', 'not', 'will', 'her', 'already', 'then', 'should', 'these', "'d", 'everywhere', 'on', 'from', 'although', 'and', 'whenever', 'just', 'nevertheless', 'his', 'twelve', 'during', 'forty', 'each', 'nine', 'everything', 'off', 'really', 'more', 'either', 'quite', 'does', 'afterwards', 'an', 'could', 'call', 'before', 'whom', '‘d', 'with', 'less', 'wherever', 'out', 'about', 'yours', '’ve', 'beside', 'therein', 'what', 'nothing', 'herself', 'i', 'seem', 'became', 'becoming', 'who', 'five', 'one', 'also', 'myself', 'behind', 'two', '‘ve', 'only', 'becomes', 'over', 'as', 'me', 'someone', 'thus', 'fifty', 'where', 'indeed', 'using', 'through', 'it', 'have', 'whatever', 'those', 'thence', 'are', 'together', 'say', 'that', 'become', 'further', 'amongst', 'is', 'other', 'to', 'them', 'sometimes', 'between', '’re', 'full', 'both', 'used', 'itself', 'whence', 'elsewhere', 'besides', 'anyway', 'moreover', 'once', 'because', 'bottom', 'due', 'whole', 'himself', 'above', 'would', 'across', 'beyond', 'six', 'how', 'regarding', 'into', 'put', 'none', 'toward', 'four', 'back', 'somehow', 'part', 'still', 'never', 'take', 'twenty', 'or', 'per', 'such', 'yet', 'see', 'least', 'doing', 'might', 'my', 'empty', 'hereafter', 'former', 'whether', 'by', 'ca', '‘re', 'in', 'mine', '‘m', 'along', 'next', 'various', 'around', 'within', 'throughout', 'neither', 'do', 'wherein', 'go', 'beforehand', 'ours', 'another', 'down', 'anyhow', 'whereupon', 'of', 'the', 'thereafter', 'side', 'rather', 'since', 'there', 'anything', 'too', 'latterly', 'most', 'made', 'up', 'much', 'many', 'eleven', 'n‘t', 'even', 'get', '‘s', 'sixty', 'being', 'show', 'top', "'ll", 'three', 'whereby', 'which', 'last', 'herein', 'front', 'serious', 'thereupon', 'whereafter', 'therefore', 'this', 'onto', 'has', 'otherwise', 'every', 'seeming', 'fifteen', 'can'}

# %%
# Definir el patrón para los caracteres especiales
pat = '[{}]'.format(re.escape(string.punctuation))

# Definir la función para normalizar, lematizar y eliminar puntuación
def normalize_document_remove_punct(doc):

    doc = re.sub(r'\d+', '', doc)
    # Separamos en tokens
    tokens = nlp(doc)
    
    # Quitamos puntuación, espacios y stopwords, y aplicamos lematización
    filtered_tokens = [re.sub(pat, ' ', t.lemma_.lower())  # Usamos t.lemma_ para lematizar
                       for t in tokens
                       if not t.is_stop        # Eliminar stopwords
                       and not t.is_punct      # Eliminar puntuación
                       and not t.is_space]      # Eliminar espacios]     
    
    # Juntamos de nuevo en una cadena
    doc = ' '.join(filtered_tokens)
    
    return doc

# Aplicar la función a cada elemento de la columna 'contenido' tanto en treino como en test
df['review'] = df['review'].apply(normalize_document_remove_punct)

# %%
# Reordenar las columnas
df = df[['movie', 'username', 'date', 'review', 'score', 'sentiment']]
df.head(5)
# Out:
#             movie        username          date  \
# 0  Moonlight 2016  Randomsquirrel  Jan 15, 2025
# 3  Moonlight 2016            NWR1  Mar 31, 2024
# 5  Moonlight 2016        Youngoth  Oct 16, 2023
# 6  Moonlight 2016       Dominik08  Aug 15, 2023
# 7  Moonlight 2016        AgentLvi  Jun 27, 2023
#
#                                               review  score sentiment
# 0  absolutely brilliant film character deep plot ...     10       POS
# 3  feel emotion long time chiron manifest emotion...      9       POS
# 5                    movie masterpiece deserve oscar     10       POS
# 6  refined production obvious weakness base ratio...      8       POS
# 7  decent movie story   so scoring great visual d...      7       POS

# %% [markdown]
# ## Análisis exploratorio

# %%
sns.histplot(df['score'].astype(int), bins=10, kde=False)
plt.title('Distribución de puntuaciones (score)')
plt.xlabel('Puntuación')
plt.ylabel('Número de reseñas')
plt.show()

# %%
sns.countplot(data=df, x='sentiment')
plt.title('Distribución de sentimientos')
plt.show()

# %% [markdown]
# ## Extracción de características

# %%
from sklearn.model_selection import train_test_split

# Separar para clasificación de sentimiento
X_train_sent, X_test_sent, y_train_sent, y_test_sent = train_test_split(
    df['review'], df['sentiment'], test_size=0.2, random_state=42)

# Separar para predicción del score
X_train_score, X_test_score, y_train_score, y_test_score = train_test_split(
    df['review'], df['score'].astype(int), test_size=0.2, random_state=42)

# %%
df['sentiment']
# Out:
# 0       POS
# 3       POS
# 5       POS
# 6       POS
# 7       POS
#        ...
# 1809    NEG
# 1810    NEG
# 1811    NEG
# 1812    NEG
# 1813    NEG
# Name: sentiment, Length: 1548, dtype: object

# %% [markdown]
# #### TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
vectorizer.fit(df['review'])

print("Número total de palabras únicas:", len(vectorizer.vocabulary_))
# Out:
# Número total de palabras únicas: 8974

# %%
# Ajustar vectorizador solo con los datos de entrenamiento
tfidf = TfidfVectorizer(max_features=3000)
X_train_sent_vec = tfidf.fit_transform(X_train_sent)
X_test_sent_vec = tfidf.transform(X_test_sent)

X_train_score_vec = tfidf.transform(X_train_score)
X_test_score_vec = tfidf.transform(X_test_score)

# %% [markdown]
# ##### Topic modeling

# %%
from sklearn.decomposition import NMF
from scipy.sparse import hstack  # Para concatenar sparse matrices

# Número de temas
n_topics = 20

# Topic modeling con NMF (solo sobre datos de entrenamiento)
nmf = NMF(n_components=n_topics, random_state=42)
W_train_sent = nmf.fit_transform(X_train_sent_vec)  # Representaciones temáticas del train
W_test_sent = nmf.transform(X_test_sent_vec)        # Proyección del test sobre esos mismos temas

W_train_score = nmf.transform(X_train_score_vec)
W_test_score = nmf.transform(X_test_score_vec)

# Concatenar los vectores TF-IDF con las representaciones de tópicos (W matrices)
X_train_sent_topic = hstack([X_train_sent_vec, W_train_sent])
X_test_sent_topic = hstack([X_test_sent_vec, W_test_sent])

X_train_score_topic = hstack([X_train_score_vec, W_train_score])
X_test_score_topic = hstack([X_test_score_vec, W_test_score])

# %%
# Acceder al vocabulario
feature_names = tfidf.get_feature_names_out()

# Función para mostrar las top palabras por cada tópico
def display_topics(model, feature_names, no_top_words=10):
    for topic_idx, topic in enumerate(model.components_):
        print(f"🔹 Topic {topic_idx}: ", end='')
        top_features_idx = topic.argsort()[:-no_top_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_idx]
        print(", ".join(top_features))

# Mostrar los temas
display_topics(nmf, feature_names, no_top_words=10)
# Out:
# 🔹 Topic 0: movie, think, ending, type, waste, short, not, enjoy, expect, year
# 🔹 Topic 1: film, life, know, scene, get, give, go, fan, moment, great
# 🔹 Topic 2: bad, horrible, geostorm, review, literally, stupid, crap, acting, cat, annoying
# 🔹 Topic 3: good, actor, performance, plot, pretty, away, music, far, acting, nice
# 🔹 Topic 4: funny, de, niro, comedy, grandpa, dirty, laugh, joke, efron, robert
# 🔹 Topic 5: great, decent, scoring, voice, visual, so, story, sound, stunning, animate
# 🔹 Topic 6: watch, recommend, hard, want, review, people, interesting, read, will, need
# 🔹 Topic 7: like, feel, enjoy, not, look, well, think, scene, maybe, people
# 🔹 Topic 8: action, neeson, liam, night, run, harris, take, ed, play, taken
# 🔹 Topic 9: boring, overrated, time, long, stupid, slow, find, waste, nominate, disappointing
# 🔹 Topic 10: love, recommend, beautiful, cinematography, deserve, life, woman, overrated, time, favorite
# 🔹 Topic 11: sandler, adam, performance, laugh, role, driver, enjoy, gems, uncut, star
# 🔹 Topic 12: character, plot, feel, main, time, long, way, lot, inside, development
# 🔹 Topic 13: fun, laugh, enjoy, make, seriously, entertaining, dumb, interesting, fantasy, trash
# 🔹 Topic 14: car, mcqueen, pixar, cars, franchise, original, lightning, new, improvement, animation
# 🔹 Topic 15: story, acting, end, tell, excellent, woman, interesting, bit, new, happen
# 🔹 Topic 16: la, musical, song, land, music, stone, gosling, emma, chazelle, leave
# 🔹 Topic 17: see, year, people, think, god, actually, worth, life, critic, trailer
# 🔹 Topic 18: amazing, masterpiece, incredible, recommend, war, cast, family, poor, deserve, beautifully
# 🔹 Topic 19: shining, horror, sleep, doctor, sequel, kubrick, original, king, book, definitely

# %% [markdown]
# #### Embedding preentrenado

# %%
glove_file_path = 'glove.twitter.27B.50d.txt'

# Crear un diccionario vacío para almacenar los embeddings
glove_dict = {}

# Leer el archivo y cargar los embeddings en el diccionario
with open(glove_file_path, 'r', encoding='utf-8') as f:
    for line in f:
        # Separar cada línea en la palabra y el vector
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], dtype='float32')
        glove_dict[word] = vector

# Verificar que se ha cargado correctamente el diccionario
print(f"Se han cargado {len(glove_dict)} palabras en el diccionario de GloVe.")
# Out:
# Se han cargado 1193514 palabras en el diccionario de GloVe.

# %%
# Función para convertir una reseña en un vector
def text_to_vector(text, glove_dict, dim=50):
    words = text.split()  # Dividir la reseña en palabras (suponiendo que ya están limpias)
    
    # Obtener el vector de cada palabra si está en el diccionario de GloVe
    valid_vectors = [glove_dict[word] for word in words if word in glove_dict]
    
    # Si hay palabras válidas, calcular la media de sus vectores
    if valid_vectors:
        return np.mean(valid_vectors, axis=0)
    else:
        # Si no hay palabras válidas, devolver un vector de ceros
        return np.zeros(dim)

# Aplicar la función a cada reseña en el DataFrame
X_glove = np.vstack(df['review'].apply(lambda x: text_to_vector(x, glove_dict)))

# Verificar la forma de los vectores resultantes
print(X_glove.shape)
# Out:
# (1548, 50)

# %%
# Para la tarea de clasificación de sentimiento
X_train_glove_sent, X_test_glove_sent, y_train_sent, y_test_sent = train_test_split(
    X_glove, df['sentiment'], test_size=0.2, random_state=42)

# Para la tarea de predicción del score
X_train_glove_score, X_test_glove_score, y_train_score, y_test_score = train_test_split(
    X_glove, df['score'].astype(int), test_size=0.2, random_state=42)

# %% [markdown]
# ## Modelos

# %% [markdown]
# ### TF-IDF + LR

# %% [markdown]
# #### Clasificación

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_train_sent_enc = le.fit_transform(y_train_sent)
y_test_sent_enc = le.transform(y_test_sent)

modelLR = LogisticRegression(solver='liblinear')
#Entrenamos el modelo con el conjunto de train
modelLR.fit(X_train_score_topic, y_train_sent_enc)
prediccion = modelLR.predict(X_test_score_topic)

print('Accuracy (exactitud): ', accuracy_score(y_test_sent_enc, prediccion))
# Out:
# Accuracy (exactitud):  0.635483870967742

# %% [markdown]
# ### Embedding preentrenado + LR

# %%
# Crear y entrenar el clasificador
modelLR = LogisticRegression(solver='liblinear')
modelLR.fit(X_train_glove_sent, y_train_sent_enc)

# Realizar predicciones
prediccion = modelLR.predict(X_test_glove_sent)

# Evaluar el modelo
accuracy = accuracy_score(y_test_sent_enc, prediccion)
print('Accuracy (exactitud): ', accuracy)
# Out:
# Accuracy (exactitud):  0.5903225806451613
